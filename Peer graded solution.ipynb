# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __SanskarToshniwal__

# %% [markdown]
# _I am interested in data science because i want to make a career in it as i like to play with the data and i enjoy learning more and more about data science tools._

# %% [markdown]
# ### We are writing a code to print sum of 2 numbers

# %%
print(2+3)
# Out:
# 5

# %% [markdown]
# - bullet point 1
# - bullet point 2
#
# 1. Numbered item 1
# 2. Numbered item 2
#
# <img src="url.gif" alt="Alt text that describes the graphic" title="Title text" />
#
# ***
